# %%
import numpy as np
import pandas as pd

columnNames = (
        "id",
        "date-test",
        "last-page",
        "lang",
        "rand-value",
        "date-start",
        "date-last",
        "privacy-agreement",
        "opt-out",
        "age",
        "sex",
        "education",
        "profession",
        "mood-start",
        "internet-usage-e-mails",
        "internet-usage-messenger",
        "internet-usage-encyclopedia",
        "internet-usage-youtube",
        "internet-usage-weather",
        "internet-usage-products-and-prices",
        "internet-usage-banking",
        "internet-usage-maps",
        "internet-usage-voip",
        "internet-usage-social-media-networks",
        "internet-usage-music-streaming",
        "internet-usage-video-streaming",
        "internet-usage-news",
        "internet-usage-podcasts",
        "internet-usage-blogs",
        "internet-usage-contact-portals",
        "internet-usage-news-archives",
        "internet-usage-job-portals",
        "internet-usage-twitter",
        "browsing-type",
        "internet-level",
        "meal-preparation-a-week",
        "interest-in-nutrition",
        "nutrition-habit",
        "nutrition-habit-other",
        "diet",
        "diet-other",
        "nutrition-intolerance",
        "nutrition-intolerance-other",
        "nutrition-easiness",
        "tasks-intro-video",
        "list-question-number",
        "list-restaurant-choice",
        "list-m-move",
        "list-m-click",
        "list-aoi-pois",
        "list-choice-easiness",
        "list-choice-satisfaction",
        "chord-question-number",
        "chord-restaurant-choice",
        "chord-m-move",
        "chord-m-click",
        "chord-aoi-pois",
        "chord-aoi-choosen-components",
        "chord-aoi-other-components",
        "chord-choice-easiness",
        "chord-choice-satisfaction",
        "map-question-number",
        "map-restaurant-choice",
        "map-m-move",
        "map-m-click",
        "map-aoi-components-choice",
        "map-aoi-pois",
        "map-aoi-drag-map",
        "map-aoi-drag-popup",
        "map-aoi-zoom",
        "map-choice-easiness",
        "map-choice-satisfaction",
        "sus-01",
        "sus-02",
        "sus-03",
        "sus-04",
        "sus-05",
        "sus-06",
        "sus-07",
        "sus-08",
        "sus-09",
        "sus-10",
        "quantitatively-questions-show-all-criteria",
        "quantitatively-questions-good-impression-from-viz",
        "quantitatively-questions-show-full-info",
        "quantitatively-questions-more-responsibility",
        "quantitatively-questions-show-understandable",
        "quantitatively-questions-just-show-results-no-differences",
        "preference-chord-or-map-over-list",
        "preference-reason",
        "qualitative-questions-pros-cons-chord",
        "qualitative-questions-pros-cons-map",
        "qualitative-questions-pros-cons-list",
        "highest-preferenced-viz",
        "comments",
        "mood-end",
        "contest",
        "contest-contact",
        "privacy-contact",
        "send-button",
        "duration-over-all",
        "duration-group-privacy",
        "duration-G01Q01",
        "duration-group-dropout",
        "duration-DROPOUT01",
        "duration-group-sociodemographic",
        "duration-G03Q03",
        "duration-G03Q39",
        "duration-G03Q05",
        "duration-G01Q04",
        "duration-G03Q06",
        "duration-group-internet-usage",
        "duration-G04Q55",
        "duration-G04Q17", 
        "duration-G04Q19",
        "duration-group-nutrition",
        "duration-G04Q07",
        "duration-G04Q08",
        "duration-G04Q09",
        "duration-G04Q10",
        "duration-G04Q11",
        "duration-G04Q12",
        "duration-group-tasks-intro",
        "duration-G05Q13",
        "duration-group-list-task",
        "duration-G07Q54",
        "duration-G05Q14",
        "duration-G07Q40",
        "duration-G07Q41",
        "duration-G07Q42",
        "duration-G05Q15",
        "duration-G05Q16",
        "duration-group-chord-task",
        "duration-G07Q55",
        "duration-G05Q17",
        "duration-G08Q43",
        "duration-G08Q44",
        "duration-G08Q45",
        "duration-G08Q46",
        "duration-G08Q47",
        "duration-G05Q18",
        "duration-G05Q19",
        "duration-group-map-task",
        "duration-G07Q55Copy",
        "duration-G05Q20",
        "duration-G09Q48",
        "duration-G09Q49",
        "duration-G09Q50",
        "duration-G09Q51",
        "duration-G09Q52",
        "duration-G09Q53",
        "duration-G09Q54",
        "duration-G05Q21",
        "duration-G05Q22",
        "duration-group-sus",
        "duration-G07Q28",
        "duration-group-quantitatively-and-qualitative-questions",
        "duration-G07Q29",
        "duration-G07Q35",
        "duration-G07Q30",
        "duration-G07Q32",
        "duration-G07Q37",
        "duration-G07Q33",
        "duration-G11Q57",
        "duration-group-last-questions",
        "duration-G08Q33",
        "duration-G03Q36",
        "duration-group-thanksgiving",
        "duration-G10Q36",
        "duration-G10Q37",
        "duration-G10Q38",
    )

# %store columnNames
# Out:
# Stored 'columnNames' (tuple)
